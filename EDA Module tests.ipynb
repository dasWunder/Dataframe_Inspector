# %% [markdown]
# # The plan and why
#
# 1. The plan is to develop + test a wide range of python functions and pack them into a python module to speed up and enhance EDA process in data analysis/science pipeline
# 2. Idea came up of repetitive actions while doing EDA in my investigations
# 3. The current jupyter file will be used to develop, test and generate ideas, later take them to .py file

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
# titanic passengers df
df = sns.load_dataset("titanic")

display(df.head())
display(df.info())
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
# ...
