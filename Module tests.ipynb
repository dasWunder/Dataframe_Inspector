# %% [markdown]
# # The plan and why
#
# 1. The plan is to develop + test a wide range of python functions and pack them into a python module to speed up and enhance EDA and data preprocessing processes in data analysis/science pipeline
# 2. Idea came up of repetitive actions while doing EDA and data preprocessing in my investigations
# 3. The current jupyter file will be used to develop, test and generate ideas, later take them to .py file

# %% [markdown]
# # Libraries

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from functions import summary as sm

# %% [markdown]
# # Data load

# %%
df = sns.load_dataset("mpg")
sm.head_info(df, -10)
# Out:
# ERROR:functions.summary:Invalid 'n' value: -10
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 df = sns.load_dataset("mpg")
# ----> 2 sm.head_info(df, -10)
#
# File d:\Python\DA_Modules\functions\summary.py:50, in head_info(df, n)
#      48 if not isinstance(n, int) or n < 0:
#      49     logger.error("Invalid 'n' value: %s", n)
# ---> 50     raise ValueError("n must be a non-negative integer")
#      52 # logger.info("Displaying head with n=%d", n)
#      53
#      54 # Series: manually print metadata
#      55 if isinstance(df, pd.Series):
#
# ValueError: n must be a non-negative integer

# %%
# def is_even_or_odd(num):
#     if (num % 2 == 0):
#         print('The number is even')
#     else:
#         print('The number is odd')
        
# is_even_or_odd(1000)
# Out:
# The number is even

# %%
# num = int(input("Enter a number: "))
# if (num % 2) == 0:
#    print("{0} is Even".format(num))
# else:
#    print("{0} is Odd".format(num))
# Out:
# 15 is Odd
